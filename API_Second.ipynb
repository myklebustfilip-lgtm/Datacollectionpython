# %% [markdown]
# The purpose of this notebook is to provide more examples on how to use simple APIs. As you have already learned, API stands for Application Programming Interface and is a software intermediary that allows two applications to talk to each other.
#
# The advantages of using APIs:
#  *   **Automation**. Less human effort is required and workflows can be easily updated to become faster and more
#      productive.
#  *   **Efficiency**. It allows to use the capabilities of one of the already developed APIs than to try to
#      independently implement some functionality from scratch.
#
# The disadvantage of using APIs:
#  *   **Security**. If the API is poorly integrated, it means it will be vulnerable to attacks, resulting in data breeches or losses having financial or reputation implications.
#
# One of the applications we will use in this notebook is Random User Generator. RandomUser is an open-source, free API providing developers with randomly generated users to be used as placeholders for testing purposes. This makes the tool similar to Lorem Ipsum, but is a placeholder for people instead of text. The API can return multiple results, as well as specify generated user details such as gender, email, image, username, address, title, first and last name, and more. More information on [RandomUser](https://pypi.org/project/randomuser/) can be found here.
#
# Another example of simple API we will use in this notebook is Fruityvice application. The Fruityvice API web service which provides data for all kinds of fruit! You can use Fruityvice to find out interesting information about fruit and educate yourself. The web service is completely free to use and contribute to.

# %% [markdown]
# ## Example 1: RandomUser API
# Bellow are Get Methods parameters that we can generate. For more information on the parameters, please visit this [documentation](https://randomuser.me/documentation) page.

# %% [markdown]
# ## **Get Methods**
#
# - get_cell()
# - get_city()
# - get_dob()
# - get_email()
# - get_first_name()
# - get_full_name()
# - get_gender()
# - get_id()
# - get_id_number()
# - get_id_type()
# - get_info()
# - get_last_name()
# - get_login_md5()
# - get_login_salt()
# - get_login_sha1()
# - get_login_sha256()
# - get_nat()
# - get_password()
# - get_phone()
# - get_picture()
# - get_postcode()
# - get_registered()
# - get_state()
# - get_street()
# - get_username()
# - get_zipcode()

# %% [markdown]
# To start using the API you can install the `randomuser` library running the `pip install` command.

# %%
# !pip install randomuser
# Out:
# Collecting randomuser
#   Downloading randomuser-1.6.tar.gz (5.0 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: randomuser
#   Building wheel for randomuser (setup.py) ... done
#   Created wheel for randomuser: filename=randomuser-1.6-py3-none-any.whl size=5067 sha256=0c6f90b75604b841b42bcfb8b5a18fa9a1b2c6f707b7ce20598f2d490c965c88
#   Stored in directory: /root/.cache/pip/wheels/be/62/c8/71e1b48f4758ea5b78af7595d87178f628cde315a3326610ee
# Successfully built randomuser
# Installing collected packages: randomuser
# Successfully installed randomuser-1.6

# %% [markdown]
# Then, we will load the necessary libraries.

# %%
from randomuser import RandomUser
import pandas as pd

# %% [markdown]
# First, we will create a random user object, r.

# %%
r = RandomUser()

# %% [markdown]
# Then, using `generate_users()` function, we get a list of random 10 users.

# %%
some_list = r.generate_users(10)

# %%
some_list
# Out:
# [<randomuser.RandomUser at 0x784180345010>,
#  <randomuser.RandomUser at 0x784180345040>,
#  <randomuser.RandomUser at 0x784180345070>,
#  <randomuser.RandomUser at 0x7841803450a0>,
#  <randomuser.RandomUser at 0x7841803450d0>,
#  <randomuser.RandomUser at 0x784180345100>,
#  <randomuser.RandomUser at 0x784180345130>,
#  <randomuser.RandomUser at 0x784180345160>,
#  <randomuser.RandomUser at 0x784180345190>,
#  <randomuser.RandomUser at 0x7841803451c0>]

# %% [markdown]
# The **"Get Methods"** functions mentioned at the beginning of this notebook, can generate the required parameters to construct a dataset. For example, to get full name, we call `get_full_name()` function.

# %%
name = r.get_full_name()

# %%
name
# Out:
# 'Jakub Nome'

# %% [markdown]
# Let's say we only need 10 users with full names and their email addresses. We can write a "for-loop" to print these 10 users.

# %%
for user in some_list:
    print (user.get_full_name()," ",user.get_email())
# Out:
# Jeanne Lavoie   jeanne.lavoie@example.com
# Charles Kumar   charles.kumar@example.com
# Peggy Patterson   peggy.patterson@example.com
# Tyler Patel   tyler.patel@example.com
# Noah Ouellet   noah.ouellet@example.com
# Pihla Aro   pihla.aro@example.com
# Samuel Park   samuel.park@example.com
# Tim Mathieu   tim.mathieu@example.com
# Mestan Öymen   mestan.oymen@example.com
# Décio Oliveira   decio.oliveira@example.com

# %%
for user in some_list:
    print (user.get_full_name()," ",user.get_email()," ",user.get_password()," ",user.get_phone())
# Out:
# Jeanne Lavoie   jeanne.lavoie@example.com   redrose   276-495-8567
# Charles Kumar   charles.kumar@example.com   maxime   (465)-557-4814
# Peggy Patterson   peggy.patterson@example.com   pickles   (634)-096-8890
# Tyler Patel   tyler.patel@example.com   dakota1   (268)-028-8159
# Noah Ouellet   noah.ouellet@example.com   cheers   533-310-5424
# Pihla Aro   pihla.aro@example.com   stretch   03-991-129
# Samuel Park   samuel.park@example.com   peace1   137-118-2587
# Tim Mathieu   tim.mathieu@example.com   lucy   03-54-37-86-51
# Mestan Öymen   mestan.oymen@example.com   mother   (354)-236-8378
# Décio Oliveira   decio.oliveira@example.com   stanley   (96) 8012-0224

# %% [markdown]
# ## Exercise 1
# In this Exercise, generate photos of the random 10 users.

# %%
## Write your code here

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# for user in some_list:
#     print (user.get_picture())
# ```
#
# </details>

# %% [markdown]
# To generate a table with information about the users, we can write a function containing all desirable parameters. For example, name, gender, city, etc. The parameters will depend on the requirements of the test to be performed. We call the Get Methods, listed at the beginning of this notebook. Then, we return pandas dataframe with the users.

# %%
def get_users():
    users =[]

    for user in RandomUser.generate_users(10):
        users.append({"Name":user.get_full_name(),"Gender":user.get_gender(),"City":user.get_city(),"State":user.get_state(),"Email":user.get_email(), "DOB":user.get_dob(),"Picture":user.get_picture()})

    return pd.DataFrame(users)

# %%
get_users()
# Out:
#               Name  Gender                 City                 State  \
# 0       Kurt Mills    male        Carrigtwohill              Limerick
# 1   Etienne Knight    male             Red Rock      British Columbia
# 2    Mariano Gomez    male            Santander               Melilla
# 3     Jar Stephens    male             Pasadena               Georgia
# 4  Oğuzhan Özdoğan    male              Karaman                Samsun
# 5  Nilce das Neves  female  Presidente Prudente               Paraíba
# 6      Daniel Sund    male         Moltustranda              Nordland
# 7  Landon Stephens    male                Gorey                 Clare
# 8        Ayşe Atan  female              Ardahan               Denizli
# 9    James Vetrhus    male       Helgelandsmoen  Finnmark - Finnmárku
#
#                          Email                       DOB  \
# 0       kurt.mills@example.com  1962-06-29T23:45:34.240Z
# 1   etienne.knight@example.com  1993-09-09T01:33:54.715Z
# 2    mariano.gomez@example.com  1990-02-22T04:11:39.969Z
# 3     jar.stephens@example.com  1983-09-21T08:47:08.882Z
# 4  oguzhan.ozdogan@example.com  1963-04-28T20:34:10.870Z
# 5   nilce.dasneves@example.com  1995-07-13T21:47:37.414Z
# 6      daniel.sund@example.com  1955-09-06T18:21:48.077Z
# 7  landon.stephens@example.com  1975-02-14T17:37:48.327Z
# 8        ayse.atan@example.com  1969-03-12T19:54:10.231Z
# 9    james.vetrhus@example.com  1993-08-17T16:05:02.825Z
#
#                                             Picture
# 0    https://randomuser.me/api/portraits/men/56.jpg
# 1    https://randomuser.me/api/portraits/men/30.jpg
# 2    https://randomuser.me/api/portraits/men/52.jpg
# 3     https://randomuser.me/api/portraits/men/3.jpg
# 4    https://randomuser.me/api/portraits/men/74.jpg
# 5  https://randomuser.me/api/portraits/women/41.jpg
# 6    https://randomuser.me/api/portraits/men/84.jpg
# 7    https://randomuser.me/api/portraits/men/45.jpg
# 8  https://randomuser.me/api/portraits/women/92.jpg
# 9    https://randomuser.me/api/portraits/men/87.jpg

# %%
df1 = pd.DataFrame(get_users())

# %%
df1
# Out:
#                  Name  Gender                    City          State  \
# 0        Connor White    male                Blenheim      Northland
# 1  Gonca Kulaksızoğlu  female                Tekirdağ        Antalya
# 2        Quentin Jean    male                  Angers           Aube
# 3      Jimmie Garrett    male          Port Macquarie       Victoria
# 4        Maëlys Caron  female              Argenteuil         Savoie
# 5         یلدا کامروا  female               اسلام‌شهر             قم
# 6          Ross Meyer    male                 Chicago  New Hampshire
# 7      Rafael Herrero    male  Santa Cruz de Tenerife       Asturias
# 8        Becky Wright  female                 Lincoln   Lincolnshire
# 9        Amelia Moore  female              Lower Hutt     Canterbury
#
#                             Email                       DOB  \
# 0        connor.white@example.com  1954-07-29T13:05:18.630Z
# 1  gonca.kulaksizoglu@example.com  1965-10-25T09:46:34.120Z
# 2        quentin.jean@example.com  1967-10-10T23:10:50.554Z
# 3      jimmie.garrett@example.com  1945-04-28T11:15:58.127Z
# 4        maelys.caron@example.com  1984-06-09T09:38:43.227Z
# 5           yld.khmrw@example.com  1970-12-18T21:59:21.172Z
# 6          ross.meyer@example.com  1970-01-03T12:08:11.329Z
# 7      rafael.herrero@example.com  1964-09-12T19:06:13.319Z
# 8        becky.wright@example.com  1990-11-06T00:27:31.755Z
# 9        amelia.moore@example.com  1947-03-06T22:33:51.631Z
#
#                                             Picture
# 0    https://randomuser.me/api/portraits/men/43.jpg
# 1  https://randomuser.me/api/portraits/women/41.jpg
# 2    https://randomuser.me/api/portraits/men/98.jpg
# 3     https://randomuser.me/api/portraits/men/0.jpg
# 4  https://randomuser.me/api/portraits/women/94.jpg
# 5  https://randomuser.me/api/portraits/women/73.jpg
# 6    https://randomuser.me/api/portraits/men/44.jpg
# 7    https://randomuser.me/api/portraits/men/30.jpg
# 8  https://randomuser.me/api/portraits/women/50.jpg
# 9  https://randomuser.me/api/portraits/women/32.jpg

# %% [markdown]
# Now we have a *pandas* dataframe that can be used for any testing purposes that the tester might have.

# %% [markdown]
# ## Example 2: Fruityvice API
#
# Another, more common way to use APIs, is through `requests` library.
# We will start by importing all required libraries.

# %%
import requests
import json

# %% [markdown]
# We will obtain the [fruityvice](https://www.fruityvice.com) API data using `requests.get("url")` function. The data is in a json format.

# %%
data = requests.get("https://fruityvice.com/api/fruit/all")

# %% [markdown]
# We will retrieve results using `json.loads()` function.

# %%
results = json.loads(data.text)

# %% [markdown]
# We will convert our json data into *pandas* data frame.

# %%
df_fruit = pd.DataFrame(results)
df_fruit.head()
# Out:
#          name  id      family         order      genus  \
# 0   Persimmon  52   Ebenaceae       Rosales  Diospyros
# 1  Strawberry   3    Rosaceae       Rosales   Fragaria
# 2      Banana   1    Musaceae  Zingiberales       Musa
# 3      Tomato   5  Solanaceae     Solanales    Solanum
# 4        Pear   4    Rosaceae       Rosales      Pyrus
#
#                                           nutritions
# 0  {'calories': 81, 'fat': 0.0, 'sugar': 18.0, 'c...
# 1  {'calories': 29, 'fat': 0.4, 'sugar': 5.4, 'ca...
# 2  {'calories': 96, 'fat': 0.2, 'sugar': 17.2, 'c...
# 3  {'calories': 74, 'fat': 0.2, 'sugar': 2.6, 'ca...
# 4  {'calories': 57, 'fat': 0.1, 'sugar': 10.0, 'c...

# %%
df_fruit.shape
# Out:
# (49, 6)

# %% [markdown]
# The result is in a nested json format. The 'nutrition' column contains multiple subcolumns, so the data needs to be 'flattened' or normalized.

# %%
df2 = pd.json_normalize(results)

# %%
df2
# Out:
#                   name   id           family             order         genus  \
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# 11                 Fig   68         Moraceae           Rosales         Ficus
# 12          Gooseberry   69  Grossulariaceae      Saxifragales         Ribes
# 13        Passionfruit   70   Passifloraceae      Malpighiales    Passiflora
# 14                Plum   71         Rosaceae           Rosales        Prunus
# 15              Orange    2         Rutaceae        Sapindales        Citrus
# 16          GreenApple   72         Rosaceae           Rosales         Malus
# 17           Raspberry   23         Rosaceae           Rosales         Rubus
# 18          Watermelon   25    Cucurbitaceae      Cucurbitales     Citrullus
# 19               Lemon   26         Rutaceae        Sapindales        Citrus
# 20               Mango   27    Anacardiaceae        Sapindales     Mangifera
# 21           Blueberry   33         Rosaceae           Rosales      Fragaria
# 22               Apple    6         Rosaceae           Rosales         Malus
# 23               Guava   37        Myrtaceae          Myrtales       Psidium
# 24             Apricot   35         Rosaceae           Rosales        Prunus
# 25               Melon   41    Cucurbitaceae     Cucurbitaceae       Cucumis
# 26           Tangerine   77         Rutaceae        Sapindales        Citrus
# 27            Pitahaya   78        Cactaceae    Caryophyllales     Cactaceae
# 28                Lime   44         Rutaceae        Sapindales        Citrus
# 29         Pomegranate   79       Lythraceae          Myrtales        Punica
# 30         Dragonfruit   80        Cactaceae    Caryophyllales  Selenicereus
# 31               Grape   81         Vitaceae           Vitales         Vitis
# 32               Morus   82         Moraceae           Rosales         Morus
# 33              Feijoa   76        Myrtaceae        Myrtoideae    Sellowiana
# 34             Avocado   84        Lauraceae          Laurales        Persea
# 35           Kiwifruit   85    Actinidiaceae          Ericales     Actinidia
# 36           Cranberry   87        Ericaceae          Ericales     Vaccinium
# 37              Cherry    9         Rosaceae           Rosales        Prunus
# 38               Peach   86         Rosaceae           Rosales        Prunus
# 39           Jackfruit   94         Moraceae           Rosales    Artocarpus
# 40        Horned Melon   95    Cucurbitaceae      Cucurbitales       Cucumis
# 41            Hazelnut   96       Betulaceae           Fagales       Corylus
# 42              Pomelo   98         Rutaceae        Sapindales        Citrus
# 43          Mangosteen   99       Clusiaceae      Malpighiales      Garcinia
# 44             Pumpkin  100    Cucurbitaceae      Cucurbitales     Cucurbita
# 45  Japanese Persimmon  101        Ebenaceae          Ericales     Diospyros
# 46              Papaya   42       Caricaceae       Brassicales        Carica
# 47              Annona  103       Annonaceae           Rosales       Annonas
# 48   Ceylon Gooseberry  104       Salicaceae      Malpighiales      Dovyalis
#
#     nutritions.calories  nutritions.fat  nutritions.sugar  \
# 0                    81            0.00             18.00
# 1                    29            0.40              5.40
# 2                    96            0.20             17.20
# 3                    74            0.20              2.60
# 4                    57            0.10             10.00
# 5                   147            5.30              6.75
# 6                    40            0.40              4.50
# 7                    50            0.34              5.74
# 8                    61            0.50              9.00
# 9                    66            0.44             15.00
# 10                   50            0.12              9.85
# 11                   74            0.30             16.00
# 12                   44            0.60              0.00
# 13                   97            0.70             11.20
# 14                   46            0.28              9.92
# 15                   43            0.20              8.20
# 16                   21            0.10              6.40
# 17                   53            0.70              4.40
# 18                   30            0.20              6.00
# 19                   29            0.30              2.50
# 20                   60            0.38             13.70
# 21                   29            0.40              5.40
# 22                   52            0.40             10.30
# 23                   68            1.00              9.00
# 24                   15            0.10              3.20
# 25                   34            0.00              8.00
# 26                   45            0.40              9.10
# 27                   36            0.40              3.00
# 28                   25            0.10              1.70
# 29                   83            1.20             13.70
# 30                   60            1.50              8.00
# 31                   69            0.16             16.00
# 32                   43            0.39              8.10
# 33                   44            0.40              3.00
# 34                  160           14.66              0.66
# 35                   61            0.50              8.90
# 36                   46            0.10              4.00
# 37                   50            0.30              8.00
# 38                   39            0.25              8.40
# 39                   95            0.00             19.10
# 40                   44            1.26              0.50
# 41                  628           61.00              4.30
# 42                   37            0.00              8.50
# 43                   73            0.58             16.11
# 44                   25            0.30              3.30
# 45                   70            0.20             13.00
# 46                   39            0.30              4.40
# 47                   92            0.29              3.40
# 48                   47            0.30              8.10
#
#     nutritions.carbohydrates  nutritions.protein
# 0                      18.00                0.00
# 1                       5.50                0.80
# 2                      22.00                1.00
# 3                       3.90                0.90
# 4                      15.00                0.40
# 5                      27.10                1.50
# 6                       9.00                1.30
# 7                      11.30                0.75
# 8                      15.00                1.10
# 9                      17.00                0.80
# 10                     13.12                0.54
# 11                     19.00                0.80
# 12                     10.00                0.90
# 13                     22.40                2.20
# 14                     11.40                0.70
# 15                      8.30                1.00
# 16                      3.10                0.40
# 17                     12.00                1.20
# 18                      8.00                0.60
# 19                      9.00                1.10
# 20                     15.00                0.82
# 21                      5.50                0.00
# 22                     11.40                0.30
# 23                     14.00                2.60
# 24                      3.90                0.50
# 25                      8.00                0.00
# 26                      8.30                0.00
# 27                      7.00                1.00
# 28                      8.40                0.30
# 29                     18.70                1.70
# 30                      9.00                9.00
# 31                     18.10                0.72
# 32                      9.80                1.44
# 33                      8.00                0.60
# 34                      8.53                2.00
# 35                     14.60                1.14
# 36                     12.20                0.40
# 37                     12.00                1.00
# 38                      9.50                0.90
# 39                     23.20                1.72
# 40                      7.56                1.78
# 41                     17.00               15.00
# 42                      9.67                0.82
# 43                     17.91                0.41
# 44                      4.60                1.10
# 45                     19.00                0.60
# 46                      5.80                0.50
# 47                     19.10                1.50
# 48                      9.60                1.20

# %% [markdown]
# Let's see if we can extract some information from this dataframe. Perhaps, we need to know the family and genus of a cherry.

# %%
cherry = df2.loc[df2["name"] == 'Cherry']
(cherry.iloc[0]['family']) , (cherry.iloc[0]['genus'])
# Out:
# ('Rosaceae', 'Prunus')

# %% [markdown]
# ## Exercise 2
# In this Exercise, find out how many calories are contained in a banana.

# %%
# Write your code here

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# cal_banana = df2.loc[df2["name"] == 'Banana']
# cal_banana.iloc[0]['nutritions.calories']
# ```
#
# </details>

# %% [markdown]
# ## Exercise 3
#
# This [page](https://mixedanalytics.com/blog/list-actually-free-open-no-auth-needed-apis/) contains a list of free public APIs for you to practice. Let us deal with the following example.
#
# #### Official Joke API
# This API returns random jokes from a database. The following URL can be used to retrieve 10 random jokes.
#
# https://official-joke-api.appspot.com/jokes/ten
#
# 1. Using `requests.get("url")` function, load the data from the URL.

# %%
# Write your code here

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# data2 = requests.get("https://official-joke-api.appspot.com/jokes/ten")
# ```
#
# </details>

# %% [markdown]
# 2. Retrieve results using `json.loads()` function.

# %%
# Write your code here

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# results2 = json.loads(data2.text)
# ```
#
# </details>

# %% [markdown]
# 3. Convert json data into *pandas* data frame. Drop the type and id columns.

# %%
# Write your code here

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df3 = pd.DataFrame(results2)
# df3.drop(columns=["type","id"],inplace=True)
# df3
# ```
#
# </details>

# %% [markdown]
# ## One More Example

# %%
import requests
import pandas as pd

# Fetch the bank holidays data from the API
url = "https://www.gov.uk/bank-holidays.json"
response = requests.get(url)
data = response.json()

# %%
# Create a list to hold all holiday records
holidays = []

# Loop through each division (e.g., "england-and-wales", "scotland", "northern-ireland")
for division, details in data.items():
    for event in details.get("events", []):
        # Add the division information to each event record
        event["division"] = division
        holidays.append(event)

# Convert the list of dictionaries into a DataFrame
df = pd.DataFrame(holidays)

# Display the DataFrame
df
# Out:
#                                      title        date notes  bunting  \
# 0                           New Year’s Day  2019-01-01           True
# 1                              Good Friday  2019-04-19          False
# 2                            Easter Monday  2019-04-22           True
# 3                   Early May bank holiday  2019-05-06           True
# 4                      Spring bank holiday  2019-05-27           True
# ..                                     ...         ...   ...      ...
# 274                    Spring bank holiday  2028-05-29           True
# 275  Battle of the Boyne (Orangemen’s Day)  2028-07-12          False
# 276                    Summer bank holiday  2028-08-28           True
# 277                          Christmas Day  2028-12-25           True
# 278                             Boxing Day  2028-12-26           True
#
#               division
# 0    england-and-wales
# 1    england-and-wales
# 2    england-and-wales
# 3    england-and-wales
# 4    england-and-wales
# ..                 ...
# 274   northern-ireland
# 275   northern-ireland
# 276   northern-ireland
# 277   northern-ireland
# 278   northern-ireland
#
# [279 rows x 5 columns]

# %%
df.division.value_counts()
# Out:
# division
# northern-ireland     103
# scotland              93
# england-and-wales     83
# Name: count, dtype: int64
